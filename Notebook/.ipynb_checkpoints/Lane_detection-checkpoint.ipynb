# %% [markdown]
# ## Lane Detection using OpenCv

# %% [markdown]
# ### Import necessary modules

# %%
import numpy as np
import matplotlib.image as mpimg  # for reading in images

import matplotlib.pyplot as plt
import cv2  # computer vision library

# %matplotlib inline

# %% [markdown]
# ### Read in and Display Images

# %%
# Read in the image
image1 = mpimg.imread('images/image1.jpg')
image2 = mpimg.imread('images/image2.jpg')
image3 = mpimg.imread('images/image3.jpg')
image4 = mpimg.imread('images/image4.jpg')

# %%
# display first image
plt.imshow(image1);

# %%
# display second image
plt.imshow(image2);

# %%
# display third image
plt.imshow(image3);

# %%
# display fourth image
plt.imshow(image4);
