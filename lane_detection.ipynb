# %% [markdown]
# # LANE DETECTION
# > Lane coloration has become popular in real time vehicular ad-hoc networks (VANETs). The main emphasis of this paper is to find the further ways which can be used further to improve the result of lane detection algorithms. Noise, visibility etc. can reduce the performance or the existing lane detection algorithms. The methods developed so far are working efficiently and giving good results in case when noise is not present in the images. But problem is that they fail or not give efficient results when there is any kind of noise or fog in the road images. The noise can be anything like dust, shadows, puddles, oil stains, tire skid marks, etc.

# %%
# import libraries

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
import cv2 as cv

# %%
# read the image

image = cv.imread('solidWhiteRight.jpg')

# %% [markdown]
# ## Orignal RGB Image

# %%
def orignalImage(image):
    
    images_rgb = cv.cvtColor(image, cv.COLOR_RGB2BGR)
    
#     return image

    return images_rgb



# call the function

orignalImage(image)

# plot the function

plt.imshow(image)

# %% [markdown]
# ## GrayScale Image

# %%
def grayImage(image):
    gray_image = plt.imshow(image[:,:,1], cmap="gray", interpolation=None)
    
#     return image

    return gray_image


grayImage(image)

# plt.imshow(gray_image)

# %% [markdown]
# ## HSV SCALE Image

# %%
def hsvScale(image):
    image_hsv = cv.cvtColor(images, cv.COLOR_BGR2HSV)
    
#     return image

    return image_hsv


# call the function

hsvScale(image)

# plot the function

plt.imshow(img_hsv)

# %% [markdown]
# ## HLS SCALE Image

# %%
def hlsScale(image):
    img_hsl = cv.cvtColor(images, cv.COLOR_BGR2HLS)
#     return image
    return img_hsl


# call the function

hlsScale(image)

# plot the function

plt.imshow(img_hsl)
