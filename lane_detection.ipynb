# %% [markdown]
# # LANE DETECTION
# > Lane coloration has become popular in real time vehicular ad-hoc networks (VANETs). The main emphasis of this paper is to find the further ways which can be used further to improve the result of lane detection algorithms. Noise, visibility etc. can reduce the performance or the existing lane detection algorithms. The methods developed so far are working efficiently and giving good results in case when noise is not present in the images. But problem is that they fail or not give efficient results when there is any kind of noise or fog in the road images. The noise can be anything like dust, shadows, puddles, oil stains, tire skid marks, etc.

# %%
# import libraries

import numpy as np
import matplotlib.pyplot as plt
import matplotlib.image as img
import cv2 as cv

# %% [markdown]
# ## Canny Edge Detection

# %%
# load the image
# convert it into grayscale

img = cv.imread('lane.jpeg', 0)

# canny

canny = cv.Canny(img, 100, 100)


tittles = ["image", "canny image"]

images = [img, canny]


for i in range(2):
    plt.subplot(1, 2, i+1), plt.imshow(images[i], "gray")
    plt.title(tittles[i])
    plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# # Laplacian

# %%
laplacian = cv.Laplacian(img, cv.CV_64F, ksize=3)

laplacian = np.uint8(np.absolute(laplacian))


tittles = ["image", " Laplacian"]

images = [img, laplacian]


for i in range(2):
    plt.subplot(1, 2, i+1), plt.imshow(images[i], "gray")
    plt.title(tittles[i])
    plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# # Sobel Operator

# %%
sobel_x = cv.Sobel(img, cv.CV_64F, 1, 0)

sobel_y = cv.Sobel(img, cv.CV_64F, 0, 1)

sobel_x = np.uint8(np.absolute(sobel_x))

sobel_y = np.uint8(np.absolute(sobel_y))

tittles = ["image",   "sobel_x", "sobel_y"]

images = [img,  sobel_x, sobel_y]


for i in range(3):
    plt.subplot(1, 3, i+1), plt.imshow(images[i], "gray", interpolation='nearest')

    plt.title(tittles[i])
    plt.xticks([]), plt.yticks([])

plt.show()

# %% [markdown]
# # Compare Canny, Laplacian, Sobel Operator

# %%
# canny

canny = cv.Canny(img, 100, 100)

# laplacian

laplacian = cv.Laplacian(img, cv.CV_64F, ksize=3)

laplacian = np.uint8(np.absolute(laplacian))

# sobel x and sobel y

sobel_x = cv.Sobel(img, cv.CV_64F, 1, 0)

sobel_y = cv.Sobel(img, cv.CV_64F, 0, 1)

sobel_x = np.uint8(np.absolute(sobel_x))

sobel_y = np.uint8(np.absolute(sobel_y))

tittles = ["image", "Canny", "Laplacian", "sobel_x", "sobel_y"]

images = [img, canny, laplacian, sobel_x, sobel_y]


for i in range(5):
    plt.subplot(1, 5, i+1), plt.imshow(images[i], "gray", interpolation='nearest')

    plt.title(tittles[i])
    plt.xticks([]), plt.yticks([])

plt.show()
